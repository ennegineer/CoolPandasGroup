# %%
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
import requests
from config import crimekey
from config import censuskey
from pprint import pprint
from census import Census
import scipy.stats as st

# API Setup
baseurl = "http://api.usa.gov/crime/fbi/sapi/"
c = Census(censuskey, year=2019)

# %%
URL = ("https://api.usa.gov/crime/fbi/sapi/api/summarized/state/AL/violent-crime/2019/2019?page=2&API_KEY=" + crimekey)

getdatasets = requests.get(URL)
datasets_json = getdatasets.json()
pprint(datasets_json)
# Out:
# {'pagination': {'count': 352, 'page': 2, 'pages': 18, 'per_page': 20},
#  'results': [{'actual': 40,
#               'cleared': 9,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0040000',
#               'state_abbr': 'AL'},
#              {'actual': 35,
#               'cleared': 14,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0040100',
#               'state_abbr': 'AL'},
#              {'actual': 0,
#               'cleared': 0,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0040200',
#               'state_abbr': 'AL'},
#              {'actual': 146,
#               'cleared': 110,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050000',
#               'state_abbr': 'AL'},
#              {'actual': 37,
#               'cleared': 15,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050100',
#               'state_abbr': 'AL'},
#              {'actual': 29,
#               'cleared': 21,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050200',
#               'state_abbr': 'AL'},
#              {'actual': 26,
#               'cleared': 18,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050300',
#               'state_abbr': 'AL'},
#              {'actual': 14,
#               'cleared': 2,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050400',
#               'state_abbr': 'AL'},
#              {'actual': 21,
#               'cleared': 14,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050500',
#               'state_abbr': 'AL'},
#              {'actual': 11,
#               'cleared': 6,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050600',
#               'state_abbr': 'AL'},
#              {'actual': 3,
#               'cleared': 1,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050700',
#               'state_abbr': 'AL'},
#              {'actual': 6,
#               'cleared': 4,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050800',
#               'state_abbr': 'AL'},
#              {'actual': 6,
#               'cleared': 3,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0050900',
#               'state_abbr': 'AL'},
#              {'actual': 4,
#               'cleared': 2,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0051000',
#               'state_abbr': 'AL'},
#              {'actual': 0,
#               'cleared': 0,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0051100',
#               'state_abbr': 'AL'},
#              {'actual': 11,
#               'cleared': 3,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0051200',
#               'state_abbr': 'AL'},
#              {'actual': 20,
#               'cleared': 0,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0051300',
#               'state_abbr': 'AL'},
#              {'actual': 77,
#               'cleared': 18,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0060100',
#               'state_abbr': 'AL'},
#              {'actual': 2,
#               'cleared': 1,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0060200',
#               'state_abbr': 'AL'},
#              {'actual': 0,
#               'cleared': 0,
#               'data_range': None,
#               'data_year': 2019,
#               'offense': 'violent-crime',
#               'ori': 'AL0060300',
#               'state_abbr': 'AL'}]}

# %%
# Find crime rate for each state
stateAbbs = ['AL', 'AK', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS',
            'KY', 'LA', 'MA', 'ME', 'MD', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 
            'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
statedict = {}
record = 1

# loop through all states and pull data for each
for item in stateAbbs:
    page = 0
    query_url = "https://api.usa.gov/crime/fbi/sapi/api/summarized/state/" + item + "/violent-crime/2019/2019?API_KEY=" + crimekey
    # Get response into JSON
    stateresponse = requests.get(query_url)
    statejson = stateresponse.json()
    pages = statejson['pagination']['pages']
    actuals = 0
    try:
        for j in range(pages):
            query_url = "https://api.usa.gov/crime/fbi/sapi/api/summarized/state/" + item + "/violent-crime/2019/2019?page=" + str(j) + "&API_KEY=" + crimekey
            # Get response into JSON
            stateresponse = requests.get(query_url)
            statejson = stateresponse.json()   
            x = len(statejson['results'])
            # Log each state and account for exceptions
            try:
                # Collect crime data and put it into a dictionary
                for i in range(x):
                    actuals = actuals + statejson['results'][i]['actual']
                    statedict[item] = [actuals]
                print(f"Processing record {record} | {item}")
                record += 1

            # Exception if state data isn't found
            except:
                print(f"Data not found for {item}. Skipping...")
    except:
        print(f"Page(s) not found for {item}. Skipping...")

print("----------Job complete!----------")
# Out:
# Processing record 1 | AL
# Processing record 2 | AL
# Processing record 3 | AL
# Processing record 4 | AL
# Processing record 5 | AL
# Processing record 6 | AL
# Processing record 7 | AL
# Processing record 8 | AL
# Processing record 9 | AL
# Processing record 10 | AL
# Processing record 11 | AL
# Processing record 12 | AL
# Processing record 13 | AL
# Processing record 14 | AL
# Processing record 15 | AL
# Processing record 16 | AL
# Processing record 17 | AL
# Processing record 18 | AL
# Processing record 19 | AK
# Processing record 20 | AK
# Processing record 21 | AR
# Processing record 22 | AR
# Processing record 23 | AR
# Processing record 24 | AR
# Processing record 25 | AR
# Processing record 26 | AR
# Processing record 27 | AR
# Processing record 28 | AR
# Processing record 29 | AR
# Processing record 30 | AR
# Processing record 31 | AR
# Processing record 32 | AR
# Processing record 33 | AR
# Processing record 34 | AR
# Processing record 35 | AR
# Processing record 36 | AZ
# Processing record 37 | AZ
# Processing record 38 | AZ
# Processing record 39 | AZ
# Processing record 40 | AZ
# Processing record 41 | AZ
# Processing record 42 | CA
# Processing record 43 | CA
# Processing record 44 | CA
# Processing record 45 | CA
# Processing record 46 | CA
# Processing record 47 | CA
# Processing record 48 | CA
# Processing record 49 | CA
# Processing record 50 | CA
# Processing record 51 | CA
# Processing record 52 | CA
# Processing record 53 | CA
# Processing record 54 | CA
# Processing record 55 | CA
# Processing record 56 | CA
# Processing record 57 | CA
# Processing record 58 | CA
# Processing record 59 | CA
# Processing record 60 | CA
# Processing record 61 | CA
# Processing record 62 | CA
# Processing record 63 | CA
# Processing record 64 | CA
# Processing record 65 | CA
# Processing record 66 | CA
# Processing record 67 | CA
# Processing record 68 | CA
# Processing record 69 | CA
# Processing record 70 | CA
# Processing record 71 | CA
# Processing record 72 | CA
# Processing record 73 | CA
# Processing record 74 | CA
# Processing record 75 | CA
# Processing record 76 | CA
# Processing record 77 | CA
# Processing record 78 | CA
# Processing record 79 | CO
# Processing record 80 | CO
# Processing record 81 | CO
# Processing record 82 | CO
# Processing record 83 | CO
# Processing record 84 | CO
# Processing record 85 | CO
# Processing record 86 | CO
# Processing record 87 | CO
# Processing record 88 | CO
# Processing record 89 | CO
# Processing record 90 | CO
# Processing record 91 | CT
# Processing record 92 | CT
# Processing record 93 | CT
# Processing record 94 | CT
# Processing record 95 | CT
# Processing record 96 | CT
# Processing record 97 | DE
# Processing record 98 | DE
# Processing record 99 | DE
# Processing record 100 | DC
# Processing record 101 | FL
# Processing record 102 | FL
# Processing record 103 | FL
# Processing record 104 | FL
# Processing record 105 | FL
# Processing record 106 | FL
# Processing record 107 | FL
# Processing record 108 | FL
# Processing record 109 | FL
# Processing record 110 | FL
# Processing record 111 | FL
# Processing record 112 | FL
# Processing record 113 | FL
# Processing record 114 | FL
# Processing record 115 | FL
# Processing record 116 | FL
# Processing record 117 | FL
# Processing record 118 | FL
# Processing record 119 | FL
# Processing record 120 | FL
# Processing record 121 | FL
# Processing record 122 | FL
# Processing record 123 | FL
# Processing record 124 | FL
# Processing record 125 | FL
# Processing record 126 | FL
# Processing record 127 | FL
# Processing record 128 | FL
# Processing record 129 | FL
# Processing record 130 | FL
# Processing record 131 | FL
# Processing record 132 | FL
# Processing record 133 | FL
# Processing record 134 | FL
# Processing record 135 | GA
# Processing record 136 | GA
# Processing record 137 | GA
# Processing record 138 | GA
# Processing record 139 | GA
# Processing record 140 | GA
# Processing record 141 | GA
# Processing record 142 | GA
# Processing record 143 | GA
# Processing record 144 | GA
# Processing record 145 | GA
# Processing record 146 | GA
# Processing record 147 | GA
# Processing record 148 | GA
# Processing record 149 | GA
# Processing record 150 | GA
# Processing record 151 | GA
# Processing record 152 | GA
# Processing record 153 | GA
# Processing record 154 | GA
# Processing record 155 | GA
# Processing record 156 | GA
# Processing record 157 | GA
# Processing record 158 | GA
# Processing record 159 | GA
# Processing record 160 | GA
# Processing record 161 | GA
# Processing record 162 | GA
# Processing record 163 | GA
# Processing record 164 | GA
# Processing record 165 | GA
# Processing record 166 | HI
# Processing record 167 | ID
# Processing record 168 | ID
# Processing record 169 | ID
# Processing record 170 | ID
# Processing record 171 | ID
# Processing record 172 | ID
# Processing record 173 | IL
# Processing record 174 | IL
# Processing record 175 | IL
# Processing record 176 | IL
# Processing record 177 | IL
# Processing record 178 | IL
# Processing record 179 | IL
# Processing record 180 | IL
# Processing record 181 | IL
# Processing record 182 | IL
# Processing record 183 | IL
# Processing record 184 | IL
# Processing record 185 | IL
# Processing record 186 | IL
# Processing record 187 | IL
# Processing record 188 | IL
# Processing record 189 | IL
# Processing record 190 | IL
# Processing record 191 | IL
# Processing record 192 | IL
# Processing record 193 | IL
# Processing record 194 | IL
# Processing record 195 | IL
# Processing record 196 | IL
# Processing record 197 | IL
# Processing record 198 | IL
# Processing record 199 | IL
# Processing record 200 | IL
# Processing record 201 | IL
# Processing record 202 | IL
# Processing record 203 | IL
# Processing record 204 | IL
# Processing record 205 | IL
# Processing record 206 | IL
# Processing record 207 | IL
# Processing record 208 | IL
# Processing record 209 | IL
# Processing record 210 | IL
# Processing record 211 | IL
# Processing record 212 | IN
# Processing record 213 | IN
# Processing record 214 | IN
# Processing record 215 | IN
# Processing record 216 | IN
# Processing record 217 | IN
# Processing record 218 | IN
# Processing record 219 | IN
# Processing record 220 | IN
# Processing record 221 | IN
# Processing record 222 | IN
# Processing record 223 | IN
# Processing record 224 | IN
# Processing record 225 | IN
# Processing record 226 | IA
# Processing record 227 | IA
# Processing record 228 | IA
# Processing record 229 | IA
# Processing record 230 | IA
# Processing record 231 | IA
# Processing record 232 | IA
# Processing record 233 | IA
# Processing record 234 | IA
# Processing record 235 | IA
# Processing record 236 | IA
# Processing record 237 | IA
# Processing record 238 | KS
# Processing record 239 | KS
# Processing record 240 | KS
# Processing record 241 | KS
# Processing record 242 | KS
# Processing record 243 | KS
# Processing record 244 | KS
# Processing record 245 | KS
# Processing record 246 | KS
# Processing record 247 | KS
# Processing record 248 | KS
# Processing record 249 | KS
# Processing record 250 | KS
# Processing record 251 | KS
# Processing record 252 | KS
# Processing record 253 | KS
# Processing record 254 | KS
# Processing record 255 | KY
# Processing record 256 | KY
# Processing record 257 | KY
# Processing record 258 | KY
# Processing record 259 | KY
# Processing record 260 | KY
# Processing record 261 | KY
# Processing record 262 | KY
# Processing record 263 | KY
# Processing record 264 | KY
# Processing record 265 | KY
# Processing record 266 | KY
# Processing record 267 | KY
# Processing record 268 | KY
# Processing record 269 | KY
# Processing record 270 | KY
# Processing record 271 | KY
# Processing record 272 | KY
# Processing record 273 | KY
# Processing record 274 | LA
# Processing record 275 | LA
# Processing record 276 | LA
# Processing record 277 | LA
# Processing record 278 | LA
# Processing record 279 | LA
# Processing record 280 | LA
# Processing record 281 | LA
# Processing record 282 | LA
# Processing record 283 | LA
# Processing record 284 | MA
# Processing record 285 | MA
# Processing record 286 | MA
# Processing record 287 | MA
# Processing record 288 | MA
# Processing record 289 | MA
# Processing record 290 | MA
# Processing record 291 | MA
# Processing record 292 | MA
# Processing record 293 | MA
# Processing record 294 | MA
# Processing record 295 | MA
# Processing record 296 | MA
# Processing record 297 | MA
# Processing record 298 | MA
# Processing record 299 | MA
# Processing record 300 | MA
# Processing record 301 | MA
# Processing record 302 | MA
# Processing record 303 | ME
# Processing record 304 | ME
# Processing record 305 | ME
# Processing record 306 | ME
# Processing record 307 | ME
# Processing record 308 | ME
# Processing record 309 | ME
# Processing record 310 | MD
# Processing record 311 | MD
# Processing record 312 | MD
# Processing record 313 | MD
# Processing record 314 | MD
# Processing record 315 | MD
# Processing record 316 | MD
# Processing record 317 | MD
# Processing record 318 | MI
# Processing record 319 | MI
# Processing record 320 | MI
# Processing record 321 | MI
# Processing record 322 | MI
# Processing record 323 | MI
# Processing record 324 | MI
# Processing record 325 | MI
# Processing record 326 | MI
# Processing record 327 | MI
# Processing record 328 | MI
# Processing record 329 | MI
# Processing record 330 | MI
# Processing record 331 | MI
# Processing record 332 | MI
# Processing record 333 | MI
# Processing record 334 | MI
# Processing record 335 | MI
# Processing record 336 | MI
# Processing record 337 | MI
# Processing record 338 | MI
# Processing record 339 | MI
# Processing record 340 | MI
# Processing record 341 | MI
# Processing record 342 | MI
# Processing record 343 | MI
# Processing record 344 | MI
# Processing record 345 | MI
# Processing record 346 | MI
# Processing record 347 | MI
# Processing record 348 | MI
# Processing record 349 | MI
# Processing record 350 | MN
# Processing record 351 | MN
# Processing record 352 | MN
# Processing record 353 | MN
# Processing record 354 | MN
# Processing record 355 | MN
# Processing record 356 | MN
# Processing record 357 | MN
# Processing record 358 | MN
# Processing record 359 | MN
# Processing record 360 | MN
# Processing record 361 | MN
# Processing record 362 | MN
# Processing record 363 | MN
# Processing record 364 | MN
# Processing record 365 | MN
# Processing record 366 | MN
# Processing record 367 | MN
# Processing record 368 | MN
# Processing record 369 | MN
# Processing record 370 | MN
# Processing record 371 | MO
# Processing record 372 | MO
# Processing record 373 | MO
# Processing record 374 | MO
# Processing record 375 | MO
# Processing record 376 | MO
# Processing record 377 | MO
# Processing record 378 | MO
# Processing record 379 | MO
# Processing record 380 | MO
# Processing record 381 | MO
# Processing record 382 | MO
# Processing record 383 | MO
# Processing record 384 | MO
# Processing record 385 | MO
# Processing record 386 | MO
# Processing record 387 | MO
# Processing record 388 | MO
# Processing record 389 | MO
# Processing record 390 | MO
# Processing record 391 | MO
# Processing record 392 | MO
# Processing record 393 | MO
# Processing record 394 | MO
# Processing record 395 | MO
# Processing record 396 | MO
# Processing record 397 | MO
# Processing record 398 | MO
# Processing record 399 | MO
# Processing record 400 | MS
# Processing record 401 | MS
# Processing record 402 | MS
# Processing record 403 | MS
# Processing record 404 | MS
# Processing record 405 | MT
# Processing record 406 | MT
# Processing record 407 | MT
# Processing record 408 | MT
# Processing record 409 | MT
# Processing record 410 | NC
# Processing record 411 | NC
# Processing record 412 | NC
# Processing record 413 | NC
# Processing record 414 | NC
# Processing record 415 | NC
# Processing record 416 | NC
# Processing record 417 | NC
# Processing record 418 | NC
# Processing record 419 | NC
# Processing record 420 | NC
# Processing record 421 | NC
# Processing record 422 | NC
# Processing record 423 | NC
# Processing record 424 | NC
# Processing record 425 | NC
# Processing record 426 | NC
# Processing record 427 | NC
# Processing record 428 | ND
# Processing record 429 | ND
# Processing record 430 | ND
# Processing record 431 | ND
# Processing record 432 | ND
# Processing record 433 | ND
# Processing record 434 | NE
# Processing record 435 | NE
# Processing record 436 | NE
# Processing record 437 | NE
# Processing record 438 | NE
# Processing record 439 | NE
# Processing record 440 | NE
# Processing record 441 | NE
# Processing record 442 | NE
# Processing record 443 | NE
# Processing record 444 | NE
# Processing record 445 | NE
# Processing record 446 | NH
# Processing record 447 | NH
# Processing record 448 | NH
# Processing record 449 | NH
# Processing record 450 | NH
# Processing record 451 | NH
# Processing record 452 | NH
# Processing record 453 | NH
# Processing record 454 | NH
# Processing record 455 | NH
# Processing record 456 | NJ
# Processing record 457 | NJ
# Processing record 458 | NJ
# Processing record 459 | NJ
# Processing record 460 | NJ
# Processing record 461 | NJ
# Processing record 462 | NJ
# Processing record 463 | NJ
# Processing record 464 | NJ
# Processing record 465 | NJ
# Processing record 466 | NJ
# Processing record 467 | NJ
# Processing record 468 | NJ
# Processing record 469 | NJ
# Processing record 470 | NJ
# Processing record 471 | NJ
# Processing record 472 | NJ
# Processing record 473 | NJ
# Processing record 474 | NJ
# Processing record 475 | NJ
# Processing record 476 | NJ
# Processing record 477 | NJ
# Processing record 478 | NJ
# Processing record 479 | NJ
# Processing record 480 | NJ
# Processing record 481 | NJ
# Processing record 482 | NJ
# Processing record 483 | NJ
# Processing record 484 | NJ
# Processing record 485 | NM
# Processing record 486 | NM
# Processing record 487 | NM
# Processing record 488 | NM
# Processing record 489 | NM
# Processing record 490 | NM
# Processing record 491 | NM
# Processing record 492 | NV
# Processing record 493 | NV
# Processing record 494 | NV
# Processing record 495 | NV
# Processing record 496 | NY
# Processing record 497 | NY
# Processing record 498 | NY
# Processing record 499 | NY
# Processing record 500 | NY
# Processing record 501 | NY
# Processing record 502 | NY
# Processing record 503 | NY
# Processing record 504 | NY
# Processing record 505 | NY
# Processing record 506 | NY
# Processing record 507 | NY
# Processing record 508 | NY
# Processing record 509 | NY
# Processing record 510 | NY
# Processing record 511 | NY
# Processing record 512 | NY
# Processing record 513 | NY
# Processing record 514 | NY
# Processing record 515 | NY
# Processing record 516 | NY
# Processing record 517 | NY
# Processing record 518 | NY
# Processing record 519 | NY
# Processing record 520 | NY
# Processing record 521 | NY
# Processing record 522 | NY
# Processing record 523 | NY
# Processing record 524 | NY
# Processing record 525 | OH
# Processing record 526 | OH
# Processing record 527 | OH
# Processing record 528 | OH
# Processing record 529 | OH
# Processing record 530 | OH
# Processing record 531 | OH
# Processing record 532 | OH
# Processing record 533 | OH
# Processing record 534 | OH
# Processing record 535 | OH
# Processing record 536 | OH
# Processing record 537 | OH
# Processing record 538 | OH
# Processing record 539 | OH
# Processing record 540 | OH
# Processing record 541 | OH
# Processing record 542 | OH
# Processing record 543 | OH
# Processing record 544 | OH
# Processing record 545 | OH
# Processing record 546 | OH
# Processing record 547 | OH
# Processing record 548 | OH
# Processing record 549 | OH
# Processing record 550 | OH
# Processing record 551 | OH
# Processing record 552 | OH
# Processing record 553 | OH
# Processing record 554 | OH
# Processing record 555 | OH
# Processing record 556 | OK
# Processing record 557 | OK
# Processing record 558 | OK
# Processing record 559 | OK
# Processing record 560 | OK
# Processing record 561 | OK
# Processing record 562 | OK
# Processing record 563 | OK
# Processing record 564 | OK
# Processing record 565 | OK
# Processing record 566 | OK
# Processing record 567 | OK
# Processing record 568 | OK
# Processing record 569 | OK
# Processing record 570 | OK
# Processing record 571 | OK
# Processing record 572 | OK
# Processing record 573 | OK
# Processing record 574 | OK
# Processing record 575 | OK
# Processing record 576 | OK
# Processing record 577 | OK
# Processing record 578 | OR
# Processing record 579 | OR
# Processing record 580 | OR
# Processing record 581 | OR
# Processing record 582 | OR
# Processing record 583 | OR
# Processing record 584 | OR
# Processing record 585 | OR
# Processing record 586 | OR
# Processing record 587 | OR
# Processing record 588 | PA
# Processing record 589 | PA
# Processing record 590 | PA
# Processing record 591 | PA
# Processing record 592 | PA
# Processing record 593 | PA
# Processing record 594 | PA
# Processing record 595 | PA
# Processing record 596 | PA
# Processing record 597 | PA
# Processing record 598 | PA
# Processing record 599 | PA
# Processing record 600 | PA
# Processing record 601 | PA
# Processing record 602 | PA
# Processing record 603 | PA
# Processing record 604 | PA
# Processing record 605 | PA
# Processing record 606 | PA
# Processing record 607 | PA
# Processing record 608 | PA
# Processing record 609 | PA
# Processing record 610 | PA
# Processing record 611 | PA
# Processing record 612 | PA
# Processing record 613 | PA
# Processing record 614 | PA
# Processing record 615 | PA
# Processing record 616 | PA
# Processing record 617 | PA
# Processing record 618 | PA
# Processing record 619 | PA
# Processing record 620 | PA
# Processing record 621 | PA
# Processing record 622 | PA
# Processing record 623 | PA
# Processing record 624 | PA
# Processing record 625 | PA
# Processing record 626 | PA
# Processing record 627 | PA
# Processing record 628 | PA
# Processing record 629 | PA
# Processing record 630 | PA
# Processing record 631 | PA
# Processing record 632 | PA
# Processing record 633 | PA
# Processing record 634 | PA
# Processing record 635 | PA
# Processing record 636 | PA
# Processing record 637 | PA
# Processing record 638 | PA
# Processing record 639 | PA
# Processing record 640 | PA
# Processing record 641 | PA
# Processing record 642 | PA
# Processing record 643 | PA
# Processing record 644 | PA
# Processing record 645 | PA
# Processing record 646 | PA
# Processing record 647 | PA
# Processing record 648 | PA
# Processing record 649 | PA
# Processing record 650 | PA
# Processing record 651 | PA
# Processing record 652 | PA
# Processing record 653 | PA
# Processing record 654 | PA
# Processing record 655 | PA
# Processing record 656 | PA
# Processing record 657 | PA
# Processing record 658 | PA
# Processing record 659 | PA
# Processing record 660 | PA
# Processing record 661 | PA
# Processing record 662 | RI
# Processing record 663 | RI
# Processing record 664 | RI
# Processing record 665 | SC
# Processing record 666 | SC
# Processing record 667 | SC
# Processing record 668 | SC
# Processing record 669 | SC
# Processing record 670 | SC
# Processing record 671 | SC
# Processing record 672 | SC
# Processing record 673 | SC
# Processing record 674 | SC
# Processing record 675 | SC
# Processing record 676 | SC
# Processing record 677 | SC
# Processing record 678 | SD
# Processing record 679 | SD
# Processing record 680 | SD
# Processing record 681 | SD
# Processing record 682 | SD
# Processing record 683 | SD
# Processing record 684 | SD
# Processing record 685 | TN
# Processing record 686 | TN
# Processing record 687 | TN
# Processing record 688 | TN
# Processing record 689 | TN
# Processing record 690 | TN
# Processing record 691 | TN
# Processing record 692 | TN
# Processing record 693 | TN
# Processing record 694 | TN
# Processing record 695 | TN
# Processing record 696 | TN
# Processing record 697 | TN
# Processing record 698 | TN
# Processing record 699 | TN
# Processing record 700 | TN
# Processing record 701 | TN
# Processing record 702 | TN
# Processing record 703 | TN
# Processing record 704 | TN
# Processing record 705 | TN
# Processing record 706 | TN
# Processing record 707 | TX
# Processing record 708 | TX
# Processing record 709 | TX
# Processing record 710 | TX
# Processing record 711 | TX
# Processing record 712 | TX
# Processing record 713 | TX
# Processing record 714 | TX
# Processing record 715 | TX
# Processing record 716 | TX
# Processing record 717 | TX
# Processing record 718 | TX
# Processing record 719 | TX
# Processing record 720 | TX
# Processing record 721 | TX
# Processing record 722 | TX
# Processing record 723 | TX
# Processing record 724 | TX
# Processing record 725 | TX
# Processing record 726 | TX
# Processing record 727 | TX
# Processing record 728 | TX
# Processing record 729 | TX
# Processing record 730 | TX
# Processing record 731 | TX
# Processing record 732 | TX
# Processing record 733 | TX
# Processing record 734 | TX
# Processing record 735 | TX
# Processing record 736 | TX
# Processing record 737 | TX
# Processing record 738 | TX
# Processing record 739 | TX
# Processing record 740 | TX
# Processing record 741 | TX
# Processing record 742 | TX
# Processing record 743 | TX
# Processing record 744 | TX
# Processing record 745 | TX
# Processing record 746 | TX
# Processing record 747 | TX
# Processing record 748 | TX
# Processing record 749 | TX
# Processing record 750 | TX
# Processing record 751 | TX
# Processing record 752 | TX
# Processing record 753 | TX
# Processing record 754 | TX
# Processing record 755 | TX
# Processing record 756 | TX
# Processing record 757 | TX
# Processing record 758 | TX
# Processing record 759 | TX
# Processing record 760 | TX
# Processing record 761 | UT
# Processing record 762 | UT
# Processing record 763 | UT
# Processing record 764 | UT
# Processing record 765 | UT
# Processing record 766 | UT
# Processing record 767 | UT
# Processing record 768 | VA
# Processing record 769 | VA
# Processing record 770 | VA
# Processing record 771 | VA
# Processing record 772 | VA
# Processing record 773 | VA
# Processing record 774 | VA
# Processing record 775 | VA
# Processing record 776 | VA
# Processing record 777 | VA
# Processing record 778 | VA
# Processing record 779 | VA
# Processing record 780 | VA
# Processing record 781 | VA
# Processing record 782 | VA
# Processing record 783 | VA
# Processing record 784 | VA
# Processing record 785 | VA
# Processing record 786 | VA
# Processing record 787 | VA
# Processing record 788 | VT
# Processing record 789 | VT
# Processing record 790 | VT
# Processing record 791 | VT
# Processing record 792 | VT
# Processing record 793 | WA
# Processing record 794 | WA
# Processing record 795 | WA
# Processing record 796 | WA
# Processing record 797 | WA
# Processing record 798 | WA
# Processing record 799 | WA
# Processing record 800 | WA
# Processing record 801 | WA
# Processing record 802 | WA
# Processing record 803 | WA
# Processing record 804 | WA
# Processing record 805 | WA
# Processing record 806 | WI
# Processing record 807 | WI
# Processing record 808 | WI
# Processing record 809 | WI
# Processing record 810 | WI
# Processing record 811 | WI
# Processing record 812 | WI
# Processing record 813 | WI
# Processing record 814 | WI
# Processing record 815 | WI
# Processing record 816 | WI
# Processing record 817 | WI
# Processing record 818 | WI
# Processing record 819 | WI
# Processing record 820 | WI
# Processing record 821 | WI
# Processing record 822 | WI
# Processing record 823 | WI
# Processing record 824 | WI
# Processing record 825 | WI
# Processing record 826 | WI
# Processing record 827 | WI
# Processing record 828 | WV
# Processing record 829 | WV
# Processing record 830 | WV
# Processing record 831 | WV
# Processing record 832 | WV
# Processing record 833 | WV
# Processing record 834 | WV
# Processing record 835 | WV
# Processing record 836 | WV
# Processing record 837 | WV
# Processing record 838 | WY
# Processing record 839 | WY
# Processing record 840 | WY
# ----------Job complete!----------

# %%
# Convert the dictionary into a dataframe
statedf = pd.DataFrame.from_dict(statedict, orient='index')
statedf.head()
# Out:
#          0
# AL    9504
# AK    6343
# AR   17096
# AZ   31198
# CA  173298

# %%
# Merge state names and abbreviations to match to Census data

stateNames = {
  "AL" : "Alabama",
  "AK" : "Alaska",
  "AZ" : "Arizona",
  "AR" : "Arkansas",
  "CA" : "California",
  "CO" : "Colorado",
  "CT" : "Connecticut",
  "DE" : "Delaware",
  "FL" : "Florida",
  "GA" : "Georgia",
  "HI" : "Hawaii",
  "ID" : "Idaho",
  "IL" : "Illinois",
  "IN" : "Indiana",
  "IA" : "Iowa",
  "KS" : "Kansas",
  "KY" : "Kentucky",
  "LA" : "Louisiana",
  "ME" : "Maine",
  "MD" : "Maryland",
  "MA" : "Massachusetts",
  "MI" : "Michigan",
  "MN" : "Minnesota",
  "MS" : "Mississippi",
  "MO" : "Missouri",
  "MT" : "Montana",
  "NE" : "Nebraska",
  "NV" : "Nevada",
  "NH" : "New Hampshire",
  "NJ" : "New Jersey",
  "NM" : "New Mexico",
  "NY" : "New York",
  "NC" : "North Carolina",
  "ND" : "North Dakota",
  "OH" : "Ohio",
  "OK" : "Oklahoma",
  "OR" : "Oregon",
  "PA" : "Pennsylvania",
  "RI" : "Rhode Island",
  "SC" : "South Carolina",
  "SD" : "South Dakota",
  "TN" : "Tennessee",
  "TX" : "Texas",
  "UT" : "Utah",
  "VT" : "Vermont",
  "VA" : "Virginia",
  "WA" : "Washington",
  "WV" : "West Virginia",
  "WI" : "Wisconsin",
  "WY" : "Wyoming",
  "DC" : "District of Columbia"
}

stateNamedf = pd.DataFrame.from_dict(stateNames, orient='index')

# Merge the datasets using the sate columns
statemerge = pd.merge(statedf, stateNamedf, left_index=True, right_index=True)
statemerge.rename(columns={'0_x': 'Actuals', '0_y': 'Name'}, inplace=True)
statemerge.head()
# Out:
#     Actuals        Name
# AL     9504     Alabama
# AK     6343      Alaska
# AR    17096    Arkansas
# AZ    31198     Arizona
# CA   173298  California

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
census_pd["Unemployment Rate"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["State", "Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate", "Unemployment Rate"]]

census_pd.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765

# %%
# Merge crime data with Census data
alldata = pd.merge(census_pd, statemerge, how="left", on="Name")
alldata.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate   Actuals
# 0            27928.0       795989.0     16.323794           2.708946    9504.0
# 1            36787.0        76933.0     10.437707           3.637114    6343.0
# 2            30694.0      1043764.0     14.804535           2.778676   31198.0
# 3            26577.0       496260.0     16.545475           2.349860   17096.0
# 4            36955.0      5149742.0     13.109174           3.052765  173298.0

# %%
alldata["Crime Rate"] = alldata["Actuals"] / alldata["Population"] * 100
alldata.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate  \
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765
#
#     Actuals  Crime Rate
# 0    9504.0    0.194904
# 1    6343.0    0.860572
# 2   31198.0    0.442506
# 3   17096.0    0.569986
# 4  173298.0    0.441147

# %%
cleandata = alldata.dropna(how='any')
cleandata.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate  \
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765
#
#     Actuals  Crime Rate
# 0    9504.0    0.194904
# 1    6343.0    0.860572
# 2   31198.0    0.442506
# 3   17096.0    0.569986
# 4  173298.0    0.441147

# %%
cleandata.rename(columns={'Name': 'State Name', 'Actuals': 'Violent Crime Count'}, inplace=True)
cleandata.head()
# Out:
# C:\Users\brand\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#   State  State Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate  \
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765
#
#    Violent Crime Count  Crime Rate
# 0               9504.0    0.194904
# 1               6343.0    0.860572
# 2              31198.0    0.442506
# 3              17096.0    0.569986
# 4             173298.0    0.441147

# %%
# Calculate crime rate percentage by dividing actuals by population
alldata["Crime Rate"] = alldata["Actuals"] / alldata["Population"] * 1000
alldata.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate  \
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765
#
#     Actuals  Crime Rate
# 0    9504.0    1.949039
# 1    6343.0    8.605719
# 2   31198.0    4.425061
# 3   17096.0    5.699864
# 4  173298.0    4.411471

# %%
# Puerto Rico has no crime data. Drop this row.
cleandata = alldata.dropna(how='any')
cleandata.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate  \
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765
#
#     Actuals  Crime Rate
# 0    9504.0    1.949039
# 1    6343.0    8.605719
# 2   31198.0    4.425061
# 3   17096.0    5.699864
# 4  173298.0    4.411471

# %%
# Rename columns to better describe the data
censusCrimeData = cleandata.rename(columns={'Name': 'State Name', 'Actuals': 'Violent Crime Count'})
censusCrimeData.head()
# Out:
#   State  State Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4876250.0        39.0           50536.0
# 1    02      Alaska    737068.0        34.3           77640.0
# 2    04     Arizona   7050299.0        37.7           58945.0
# 3    05    Arkansas   2999370.0        38.1           47597.0
# 4    06  California  39283497.0        36.5           75235.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Unemployment Rate  \
# 0            27928.0       795989.0     16.323794           2.708946
# 1            36787.0        76933.0     10.437707           3.637114
# 2            30694.0      1043764.0     14.804535           2.778676
# 3            26577.0       496260.0     16.545475           2.349860
# 4            36955.0      5149742.0     13.109174           3.052765
#
#    Violent Crime Count  Crime Rate
# 0               9504.0    1.949039
# 1               6343.0    8.605719
# 2              31198.0    4.425061
# 3              17096.0    5.699864
# 4             173298.0    4.411471

# %%
chartdata = censusCrimeData.filter(['State Name','Population','Unemployment Rate','Violent Crime Count','Crime Rate'])
chartdata.sort_values(by=['Crime Rate'], inplace=True,ascending=False)
chartdata.head(10)
# Out:
#               State Name  Population  Unemployment Rate  Violent Crime Count  \
# 7   District of Columbia    692683.0           4.037489               7403.0
# 1                 Alaska    737068.0           3.637114               6343.0
# 31            New Mexico   2092454.0           3.032707              15633.0
# 42             Tennessee   6709356.0           2.575493              40883.0
# 3               Arkansas   2999370.0           2.349860              17096.0
# 18             Louisiana   4664362.0           3.023350              24192.0
# 28                Nevada   2972382.0           3.109493              15269.0
# 40        South Carolina   5020806.0           2.778956              25649.0
# 25              Missouri   6104910.0           2.289780              30578.0
# 20              Maryland   6018848.0           2.731353              27514.0
#
#     Crime Rate
# 7    10.687428
# 1     8.605719
# 31    7.471132
# 42    6.093431
# 3     5.699864
# 18    5.186561
# 28    5.136957
# 40    5.108542
# 25    5.008755
# 20    4.571307

# %%
data_dict = {'District of Columbia':10.687428, 'Alaska':8.605719, 'New Mexico':7.471132,'Tennessee':6.093431, 
             'Arkansas':5.699864, 'Louisiana':5.186561,'Nevada':5.136957, 'South Carolina':5.108542, 'Missouri':5.008755,
             'Maryland':4.571307}
state = list(data_dict.keys())
unemployment = list(data_dict.values())
fig = plt.figure(figsize = (10, 5))

plt.bar(state, unemployment, color ='blue',
        width = 0.5)
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("State")
plt.ylabel("Crime Rate (%)")
plt.title("States with the Highest Crime Rate")
plt.savefig('crimerate_bar.png')
plt.show()

# %%
data_dict = {'District of Columbia':4.037489, 'Alaska':3.637114, 'Mississippi':3.341791,'Connecticut':3.257443, 
             'Nevada':3.109493, 'Illinois':3.092886,'California':3.052765, 'New Mexico':3.032707, 'Louisiana':3.023350,
             'Michigan':2.949184}
state = list(data_dict.keys())
unemployment = list(data_dict.values())
fig = plt.figure(figsize = (10, 5))

plt.bar(state, unemployment, color ='red',
        width = 0.5)
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("State")
plt.ylabel("Unemployment Rate (%)")
plt.title("States with the Highest Unemployment Rate")
plt.savefig('unemployment_bar.png')
plt.show()

# %%
plt.scatter(censusCrimeData['Unemployment Rate'],censusCrimeData['Crime Rate'])

# Add the linear regression equation and line to plot
x_values = censusCrimeData['Unemployment Rate']
y_values = censusCrimeData['Crime Rate']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1.5,8),fontsize=15,color="red")
plt.xlabel('Unemployment Rate')
plt.ylabel('Violent Crime Rate')
plt.savefig('unemploymentscatter.png')
plt.show()

# %%
correlation = st.pearsonr(x_values, y_values)
correlation
# Out:
# (0.5129600852334537, 0.00011866951928116001)
